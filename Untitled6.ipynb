# %% [markdown]
# <a href="https://colab.research.google.com/github/pournimagithub/Pournima/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
tips = sns.load_dataset("tips")

# Create violinplot
sns.violinplot(x = "total_bill", data=tips)

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
iris = sns.load_dataset("iris")
sns.swarmplot(x="species", y="petal_length", data=iris)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
x =['sun', 'mon', 'fri', 'sat', 'tue', 'wed', 'thu']
y =[5, 6.7, 4, 6, 2, 4.9, 1.8]
ax = sns.stripplot(x, y);
ax.set(xlabel ='Days', ylabel ='Amount_spend')
plt.title('My first graph');
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
iris = sns.load_dataset('iris')
ax = sns.stripplot(x='species', y='sepal_length', data=iris)
plt.title('Graph')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
iris = sns.load_dataset('iris')
ax = sns.swarmplot(x='species', y='sepal_length', data=iris)
plt.title('Graph')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
iris = sns.load_dataset('iris')
ax = sns.swarmplot(x='sepal_length', y='species', data=iris)
plt.title('Graph')
plt.show()

# %%
import seaborn as sns
df = sns.load_dataset('tips')
sns.barplot(x ='sex', y ='total_bill', data = df, 
            palette ='plasma')

# %%
import seaborn as sns
df = sns.load_dataset('tips')
sns.countplot(x ='sex', data = df)
